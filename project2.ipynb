# %% [markdown]
# # HK_student

# %% [markdown]
# ## Replicate the graph

# %% [markdown]
# ### Original graph
# ![Original graph](https://www.chinadailyhk.com/attachments/image/105/226/70/406446_117187/406446_117187_800_auto_jpg.jpg)

# %% [markdown]
# ### Import packages needed and read the data

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.path import Path
from matplotlib.patches import PathPatch
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

data = pd.read_excel('data_pj2.xlsx',index_col = 'date')

# %%
data
# Out:
#        SFS   PFU   PFS  SFU
# date
# 2000   2.6  14.2   6.9  0.3
# 2001   6.1  14.6   7.5  0.6
# 2002   7.6  15.0  10.0  1.0
# 2003   9.1  14.8  11.2  1.4
# 2004  17.2  15.0   9.8  1.8
# 2005  21.0  15.3   8.5  2.0
# 2006  21.0  15.6   9.7  2.4
# 2007  23.7  16.0   9.5  3.2
# 2008  21.4  16.2  10.0  3.6
# 2009  26.2  16.4  10.9  3.3
# 2010  31.0  16.6   8.2  3.7
# 2011  27.0  16.9   7.5  4.0
# 2012  33.4  31.6  10.0  6.7
# 2013  22.4  17.3  11.5  6.0
# 2014  20.7  17.5  12.5  6.9
# 2015  20.0  17.8  12.9  6.5
# 2016  19.0  18.0  12.7  6.2

# %% [markdown]
# ### Replicating

# %%
# Draw the lines
fig, ax=plt.subplots(figsize=(16, 9.4))
ax.plot(data.PFU, color='#67BFBA',linewidth=4)
ax.plot(data.PFS, color='#818181',linewidth=4)
ax.plot(data.SFS, color='#C06939',linewidth=4)
ax.plot(data.SFU, color='#67A77C',linewidth=4)

# Remove the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Draw the title
plt.ylim((0,35))
ax.text(1999.7,33,'Dramatic expansion in self-financing',fontdict=dict(fontsize=20,
                                                                       color='#073570',
                                                                       family='Arial Narrow',
                                                                       weight='bold'))
ax.text(1999.7,31,'sub-degree programs from 2003-04',fontdict=dict(fontsize=20,
                                                                   color='#073570',
                                                                   family='Arial Narrow',
                                                                   weight='bold'))

# Draw the legende
ax.add_patch(plt.Rectangle((1999.8,21.5),5.1,8,color='#E4E4E4'))
x=np.linspace(2004,2004.8)
ax.text(2000.34,28.3,'Self-financing sub-degree',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.plot(x,[28.5 for i in range(len(x))],color='#C06939',linewidth=4)
ax.plot(2004.4,28.5,marker='o',color='#C06939',markerfacecolor='w',ms=12)

ax.text(1999.9,26.3,'Publicly-funded undegraduate',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.plot(x,[26.5 for i in range(len(x))],color='#67BFBA',linewidth=4)
ax.plot(2004.4,26.5,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)

ax.text(2000.13,24.3,'Publicly-funded sub-degree',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.plot(x,[24.5 for i in range(len(x))],color='#818181',linewidth=4)
ax.plot(2004.4,24.5,marker='o',color='#818181',markerfacecolor='w',ms=12)

ax.text(2000.07,22.3,'Self-financing undegraduate',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.plot(x,[22.5 for i in range(len(x))],color='#67A77C',linewidth=4)
ax.plot(2004.4,22.5,marker='o',color='#67A77C',markerfacecolor='w',ms=12)

# Draw the dialog box
path_data =[
(Path.MOVETO,(2012.1,33.3)),
(Path.LINETO,(2013,32.4)),
(Path.LINETO,(2013,34.4)),
(Path.LINETO,(2016,34.4)),
(Path.LINETO,(2016,29)),
(Path.LINETO,(2013,29)),
(Path.LINETO,(2013,31.4)),
(Path.CLOSEPOLY,(2012.1,33.3)),
]
codes, verts = zip(*path_data)
path =Path(verts, codes)
patch =PathPatch(path, facecolor='#FEE0BE', alpha=0.9)
ax.add_patch(patch)

# Add text in the dialog box
x, y = zip(*path.vertices)
line,= ax.plot(x, y,'-',color='#FEE0BE')
ax.text(2013.3,33.4,'The 2012-13 academic',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,32.6,'year saw a double cohort',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,31.8,'of A-level and Hong Kong',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,31,'Diploma of Secondary',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,30.2,'Education students',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,29.4,'graduating together.',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,29.4,'graduating together.',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))

# Draw the start points
ax.plot(2000,0.3,marker='o',color='#67A77C',markerfacecolor='w',ms=12)
ax.text(1999.8,1,'0.3',fontdict=dict(fontsize=12,color='#67A77C',family='Arial Narrow'))
ax.plot(2000,2.6,marker='o',color='#C06939',markerfacecolor='w',ms=12)
ax.text(1999.6,3.3,'2.6',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.plot(2000,15,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)
ax.text(1999.8,15.7,'14.2',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))
ax.plot(2000,6.9,marker='o',color='#818181',markerfacecolor='w',ms=12)
ax.text(1999.8,7.6,'6.9',fontdict=dict(fontsize=12,color='#818181',family='Arial Narrow'))

# Draw the highest points
plt.xlim((1999.5,2018))
ax.text(2011.2,34,'33.4',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.text(2011.2,33.2,'31.6',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))

# Draw the end points
ax.plot(2016,6.2,marker='o',color='#67A77C',markerfacecolor='w',ms=12)
ax.text(2015.8,6.9,'6.2',fontdict=dict(fontsize=12,color='#67A77C',family='Arial Narrow'))
ax.plot(2016,19,marker='o',color='#C06939',markerfacecolor='w',ms=12)
ax.text(2015.8,19.7,'19.0',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.plot(2016,18,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)
ax.text(2015.8,16.7,'18.0',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))
ax.plot(2016,12.7,marker='o',color='#818181',markerfacecolor='w',ms=12)
ax.text(2015.8,13.4,'12.7',fontdict=dict(fontsize=12,color='#818181',family='Arial Narrow'))
ax.text(1999,35.5,"unit:'000")

# Set ticks and show the diagram
my_x_ticks = np.arange(2000,2017, 4)
plt.xticks(my_x_ticks)
ax.set_xticklabels(('2000-01','2004-05','2008-09', '2012-13', '2016-17'))
xminorLocator = MultipleLocator(1) 
ax.xaxis.set_minor_locator(xminorLocator)
plt.show()
# Out:
# C:\Users\Public\anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['Arial Narrow'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Improve the graph

# %% [markdown]
# ### Correcting the mistakes that the start point of blue line is not in its right position

# %%
# Draw the lines
fig, ax=plt.subplots(figsize=(16, 9.4))
ax.plot(data.PFU, color='#67BFBA',linewidth=4)
ax.plot(data.PFS, color='#818181',linewidth=4)
ax.plot(data.SFS, color='#C06939',linewidth=4)
ax.plot(data.SFU, color='#67A77C',linewidth=4)

# Remove the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Draw the title
plt.ylim((0,35))
ax.text(1999.7,33,'Dramatic expansion in self-financing',fontdict=dict(fontsize=20,
                                                                       color='#073570',
                                                                       family='Arial Narrow',
                                                                       weight='bold'))
ax.text(1999.7,31,'sub-degree programs from 2003-04',fontdict=dict(fontsize=20,
                                                                   color='#073570',
                                                                   family='Arial Narrow',
                                                                   weight='bold'))

# Draw the legende
ax.add_patch(plt.Rectangle((1999.8,21.5),5.1,8,color='#E4E4E4'))
x=np.linspace(2004,2004.8)
ax.text(2000.34,28.3,'Self-financing sub-degree',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.plot(x,[28.5 for i in range(len(x))],color='#C06939',linewidth=4)
ax.plot(2004.4,28.5,marker='o',color='#C06939',markerfacecolor='w',ms=12)

ax.text(1999.9,26.3,'Publicly-funded undegraduate',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.plot(x,[26.5 for i in range(len(x))],color='#67BFBA',linewidth=4)
ax.plot(2004.4,26.5,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)

ax.text(2000.13,24.3,'Publicly-funded sub-degree',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.plot(x,[24.5 for i in range(len(x))],color='#818181',linewidth=4)
ax.plot(2004.4,24.5,marker='o',color='#818181',markerfacecolor='w',ms=12)

ax.text(2000.07,22.3,'Self-financing undegraduate',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.plot(x,[22.5 for i in range(len(x))],color='#67A77C',linewidth=4)
ax.plot(2004.4,22.5,marker='o',color='#67A77C',markerfacecolor='w',ms=12)

# Draw the dialog box
path_data =[
(Path.MOVETO,(2012.1,33.3)),
(Path.LINETO,(2013,32.4)),
(Path.LINETO,(2013,34.4)),
(Path.LINETO,(2016,34.4)),
(Path.LINETO,(2016,29)),
(Path.LINETO,(2013,29)),
(Path.LINETO,(2013,31.4)),
(Path.CLOSEPOLY,(2012.1,33.3)),
]
codes, verts = zip(*path_data)
path =Path(verts, codes)
patch =PathPatch(path, facecolor='#FEE0BE', alpha=0.9)
ax.add_patch(patch)
x, y = zip(*path.vertices)
line,= ax.plot(x, y,'-',color='#FEE0BE')

# Add text in the dialog box
ax.text(2013.3,33.4,'The 2012-13 academic',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,32.6,'year saw a double cohort',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,31.8,'of A-level and Hong Kong',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,31,'Diploma of Secondary',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,30.2,'Education students',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,29.4,'graduating together.',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))
ax.text(2013.3,29.4,'graduating together.',fontdict=dict(fontsize=12,
                                                           family='Arial Narrow'))

# Draw the start points
ax.plot(2000,0.3,marker='o',color='#67A77C',markerfacecolor='w',ms=12)
ax.text(1999.8,1,'0.3',fontdict=dict(fontsize=12,color='#67A77C',family='Arial Narrow'))
ax.plot(2000,2.6,marker='o',color='#C06939',markerfacecolor='w',ms=12)
ax.text(1999.6,3.3,'2.6',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.plot(2000,14.2,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)
ax.text(1999.8,14.9,'14.2',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))
ax.plot(2000,6.9,marker='o',color='#818181',markerfacecolor='w',ms=12)
ax.text(1999.8,7.6,'6.9',fontdict=dict(fontsize=12,color='#818181',family='Arial Narrow'))

# Draw the highest points
plt.xlim((1999.5,2018))
ax.text(2011.2,34,'33.4',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.text(2011.2,33.2,'31.6',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))

# Draw the end points
ax.plot(2016,6.2,marker='o',color='#67A77C',markerfacecolor='w',ms=12)
ax.text(2015.8,6.9,'6.2',fontdict=dict(fontsize=12,color='#67A77C',family='Arial Narrow'))
ax.plot(2016,19,marker='o',color='#C06939',markerfacecolor='w',ms=12)
ax.text(2015.8,19.7,'19.0',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.plot(2016,18,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)
ax.text(2015.8,16.7,'18.0',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))
ax.plot(2016,12.7,marker='o',color='#818181',markerfacecolor='w',ms=12)
ax.text(2015.8,13.4,'12.7',fontdict=dict(fontsize=12,color='#818181',family='Arial Narrow'))
ax.text(1999,35.5,"unit:'000")

# Set ticks and show the diagram
my_x_ticks = np.arange(2000,2017, 4)
plt.xticks(my_x_ticks)
ax.set_xticklabels(('2000-01','2004-05','2008-09', '2012-13', '2016-17'))
xminorLocator = MultipleLocator(1) 
ax.xaxis.set_minor_locator(xminorLocator)
plt.show()
# Out:
# C:\Users\Public\anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['Arial Narrow'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Remove the dialog and replace the ledgend

# %%
# Draw the lines
fig, ax=plt.subplots(figsize=(16, 9.4))
ax.plot(data.PFU, color='#67BFBA',linewidth=4)
ax.plot(data.PFS, color='#818181',linewidth=4)
ax.plot(data.SFS, color='#C06939',linewidth=4)
ax.plot(data.SFU, color='#67A77C',linewidth=4)

# Remove the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Draw the title
plt.ylim((0,35))
ax.text(1999.7,33,'Dramatic expansion in self-financing',fontdict=dict(fontsize=20,
                                                                       color='#073570',
                                                                       family='Arial Narrow',
                                                                       weight='bold'))
ax.text(1999.7,31,'sub-degree programs from 2003-04',fontdict=dict(fontsize=20,
                                                                   color='#073570',
                                                                   family='Arial Narrow',
                                                                   weight='bold'))

#draw the ledgends at the tail of each line
ax.text(2014,22,"Self-financial sub-degree",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,16.1,"Publicly-funded undergraduate",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,10,"Publicly-funded sub-degree",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,5,"Self-financial undergraduate",fontdict=dict(fontsize=12,family='Arial Narrow'))

# Draw the start points
ax.plot(2000,0.3,marker='o',color='#67A77C',markerfacecolor='w',ms=12)
ax.text(1999.8,1,'0.3',fontdict=dict(fontsize=12,color='#67A77C',family='Arial Narrow'))
ax.plot(2000,2.6,marker='o',color='#C06939',markerfacecolor='w',ms=12)
ax.text(1999.6,3.3,'2.6',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.plot(2000,14.2,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)
ax.text(1999.8,14.9,'14.2',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))
ax.plot(2000,6.9,marker='o',color='#818181',markerfacecolor='w',ms=12)
ax.text(1999.8,7.6,'6.9',fontdict=dict(fontsize=12,color='#818181',family='Arial Narrow'))

# Draw the end points
ax.plot(2016,6.2,marker='o',color='#67A77C',markerfacecolor='w',ms=12)
ax.text(2015.8,6.9,'6.2',fontdict=dict(fontsize=12,color='#67A77C',family='Arial Narrow'))
ax.plot(2016,19,marker='o',color='#C06939',markerfacecolor='w',ms=12)
ax.text(2015.8,19.7,'19.0',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.plot(2016,18,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)
ax.text(2015.8,16.7,'18.0',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))
ax.plot(2016,12.7,marker='o',color='#818181',markerfacecolor='w',ms=12)
ax.text(2015.8,13.4,'12.7',fontdict=dict(fontsize=12,color='#818181',family='Arial Narrow'))
ax.text(1999,35.5,"unit:'000")

# Set ticks and show the diagram
my_x_ticks = np.arange(2000,2017, 4)
plt.xlim((1999.5,2018))
plt.xticks(my_x_ticks)
ax.set_xticklabels(('2000-01','2004-05','2008-09', '2012-13', '2016-17'))
xminorLocator = MultipleLocator(1) 
ax.xaxis.set_minor_locator(xminorLocator)
plt.show()
# Out:
# C:\Users\Public\anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['Arial Narrow'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Replace the title to the top of the plot and rename it

# %%
# Draw the lines
fig, ax=plt.subplots(figsize=(16, 9.4))
ax.plot(data.PFU, color='#67BFBA',linewidth=4)
ax.plot(data.PFS, color='#818181',linewidth=4)
ax.plot(data.SFS, color='#C06939',linewidth=4)
ax.plot(data.SFU, color='#67A77C',linewidth=4)

# Remove the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Draw the title
plt.title("HongKongers' participation in four education programs",fontsize=24)

#draw the ledgends at the tail of each line
ax.text(2014,22,"Self-financial sub-degree",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,16.1,"Publicly-funded undergraduate",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,10,"Publicly-funded sub-degree",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,5,"Self-financial undergraduate",fontdict=dict(fontsize=12,family='Arial Narrow'))

# Draw the start points
ax.plot(2000,0.3,marker='o',color='#67A77C',markerfacecolor='w',ms=12)
ax.text(1999.8,1,'0.3',fontdict=dict(fontsize=12,color='#67A77C',family='Arial Narrow'))
ax.plot(2000,2.6,marker='o',color='#C06939',markerfacecolor='w',ms=12)
ax.text(1999.6,3.3,'2.6',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.plot(2000,14.2,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)
ax.text(1999.8,14.9,'14.2',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))
ax.plot(2000,6.9,marker='o',color='#818181',markerfacecolor='w',ms=12)
ax.text(1999.8,7.6,'6.9',fontdict=dict(fontsize=12,color='#818181',family='Arial Narrow'))

# Draw the end points
ax.plot(2016,6.2,marker='o',color='#67A77C',markerfacecolor='w',ms=12)
ax.text(2015.8,6.9,'6.2',fontdict=dict(fontsize=12,color='#67A77C',family='Arial Narrow'))
ax.plot(2016,19,marker='o',color='#C06939',markerfacecolor='w',ms=12)
ax.text(2015.8,19.7,'19.0',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.plot(2016,18,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)
ax.text(2015.8,16.7,'18.0',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))
ax.plot(2016,12.7,marker='o',color='#818181',markerfacecolor='w',ms=12)
ax.text(2015.8,13.4,'12.7',fontdict=dict(fontsize=12,color='#818181',family='Arial Narrow'))
ax.text(1999,35.5,"unit:'000")

# Set ticks and show the diagram
my_x_ticks = np.arange(2000,2017, 4)
plt.xticks(my_x_ticks)
plt.xlim((1999.5,2018))
ax.set_xticklabels(('2000-01','2004-05','2008-09', '2012-13', '2016-17'))
xminorLocator = MultipleLocator(1) 
ax.xaxis.set_minor_locator(xminorLocator)
plt.show()
# Out:
# C:\Users\Public\anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['Arial Narrow'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Remove the left border

# %%
# Draw the lines
fig, ax=plt.subplots(figsize=(16, 9.4))
ax.plot(data.PFU, color='#67BFBA',linewidth=4)
ax.plot(data.PFS, color='#818181',linewidth=4)
ax.plot(data.SFS, color='#C06939',linewidth=4)
ax.plot(data.SFU, color='#67A77C',linewidth=4)

# Remove the top ,right and left spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

# Draw the title
plt.title("HongKongers' participation in four education programs",fontsize=24)

#draw the ledgends at the tail of each line
ax.text(2014,22,"Self-financial sub-degree",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,16.1,"Publicly-funded undergraduate",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,10,"Publicly-funded sub-degree",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,5,"Self-financial undergraduate",fontdict=dict(fontsize=12,family='Arial Narrow'))

# Draw the start points
ax.plot(2000,0.3,marker='o',color='#67A77C',markerfacecolor='w',ms=12)
ax.text(1999.8,1,'0.3',fontdict=dict(fontsize=12,color='#67A77C',family='Arial Narrow'))
ax.plot(2000,2.6,marker='o',color='#C06939',markerfacecolor='w',ms=12)
ax.text(1999.6,3.3,'2.6',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.plot(2000,14.2,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)
ax.text(1999.8,14.9,'14.2',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))
ax.plot(2000,6.9,marker='o',color='#818181',markerfacecolor='w',ms=12)
ax.text(1999.8,7.6,'6.9',fontdict=dict(fontsize=12,color='#818181',family='Arial Narrow'))

# Draw the end points
ax.plot(2016,6.2,marker='o',color='#67A77C',markerfacecolor='w',ms=12)
ax.text(2015.8,6.9,'6.2',fontdict=dict(fontsize=12,color='#67A77C',family='Arial Narrow'))
ax.plot(2016,19,marker='o',color='#C06939',markerfacecolor='w',ms=12)
ax.text(2015.8,19.7,'19.0',fontdict=dict(fontsize=12,color='#C06939',family='Arial Narrow'))
ax.plot(2016,18,marker='o',color='#67BFBA',markerfacecolor='w',ms=12)
ax.text(2015.8,16.7,'18.0',fontdict=dict(fontsize=12,color='#67BFBA',family='Arial Narrow'))
ax.plot(2016,12.7,marker='o',color='#818181',markerfacecolor='w',ms=12)
ax.text(2015.8,13.4,'12.7',fontdict=dict(fontsize=12,color='#818181',family='Arial Narrow'))


# Set ticks and show the diagram
my_x_ticks = np.arange(2000,2017, 4)
plt.xticks(my_x_ticks)
plt.xlim((1999.5,2018))
ax.set_xticklabels(('2000-01','2004-05','2008-09', '2012-13', '2016-17'))
xminorLocator = MultipleLocator(1) 
ax.xaxis.set_minor_locator(xminorLocator)
plt.yticks([])
plt.show()
# Out:
# C:\Users\Public\anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['Arial Narrow'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Change the colors of four lines

# %%
# Draw the lines
fig, ax=plt.subplots(figsize=(16, 9.4))
ax.plot(data.PFU, color='#AAADC4',linewidth=4)
ax.plot(data.PFS, color='#5C946E',linewidth=4)
ax.plot(data.SFS, color='#FF8360',linewidth=4)
ax.plot(data.SFU, color='#595758',linewidth=4)

# Remove the top ,right and left spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

# Draw the start points
ax.plot(2000,0.3,marker='o',color='#595758',markerfacecolor='w',ms=12)
ax.text(1999.8,1,'0.3',fontdict=dict(fontsize=12,color='#595758',family='Arial Narrow'))
ax.plot(2000,2.6,marker='o',color='#FF8360',markerfacecolor='w',ms=12)
ax.text(1999.6,3.3,'2.6',fontdict=dict(fontsize=12,color='#FF8360',family='Arial Narrow'))
ax.plot(2000,14.2,marker='o',color='#AAADC4',markerfacecolor='w',ms=12)
ax.text(1999.8,14.9,'14.2',fontdict=dict(fontsize=12,color='#AAADC4',family='Arial Narrow'))
ax.plot(2000,6.9,marker='o',color='#5C946E',markerfacecolor='w',ms=12)
ax.text(1999.8,7.6,'6.9',fontdict=dict(fontsize=12,color='#5C946E',family='Arial Narrow'))

# Draw the end points
ax.plot(2016,6.2,marker='o',color='#595758',markerfacecolor='w',ms=12)
ax.text(2015.8,6.9,'6.2',fontdict=dict(fontsize=12,color='#595758',family='Arial Narrow'))
ax.plot(2016,19,marker='o',color='#FF8360',markerfacecolor='w',ms=12)
ax.text(2015.8,19.7,'19.0',fontdict=dict(fontsize=12,color='#FF8360',family='Arial Narrow'))
ax.plot(2016,18,marker='o',color='#AAADC4',markerfacecolor='w',ms=12)
ax.text(2015.8,16.7,'18.0',fontdict=dict(fontsize=12,color='#AAADC4',family='Arial Narrow'))
ax.plot(2016,12.7,marker='o',color='#5C946E',markerfacecolor='w',ms=12)
ax.text(2015.8,13.4,'12.7',fontdict=dict(fontsize=12,color='#5C946E',family='Arial Narrow'))

#draw the ledgends at the tail of each line
ax.text(2014,22,"Self-financial sub-degree",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,16.1,"Publicly-funded undergraduate",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,10,"Publicly-funded sub-degree",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,5,"Self-financial undergraduate",fontdict=dict(fontsize=12,family='Arial Narrow'))
plt.title("HongKongers' participation in four education programs",fontsize=24)

# Set ticks and show the diagram
my_x_ticks = np.arange(2000,2017, 4)
plt.xticks(my_x_ticks)
ax.set_xticklabels(('2000-01','2004-05','2008-09', '2012-13', '2016-17'))
plt.xlim((1999.5,2018))
xminorLocator = MultipleLocator(1) 
ax.xaxis.set_minor_locator(xminorLocator)
plt.yticks([])
plt.show()
# Out:
# C:\Users\Public\anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['Arial Narrow'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Draw the turning point and the hightest point of the orange line

# %%
# Draw the lines
fig, ax=plt.subplots(figsize=(16, 9.4))
ax.plot(data.PFU, color='#AAADC4',linewidth=4)
ax.plot(data.PFS, color='#5C946E',linewidth=4)
ax.plot(data.SFS, color='#FF8360',linewidth=4)
ax.plot(data.SFU, color='#595758',linewidth=4)

# Remove the top ,right and left spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

# Draw the start points
ax.plot(2000,0.3,marker='o',color='#595758',markerfacecolor='w',ms=12)
ax.text(1999.8,1,'0.3',fontdict=dict(fontsize=12,color='#595758',family='Arial Narrow'))
ax.plot(2000,2.6,marker='o',color='#FF8360',markerfacecolor='w',ms=12)
ax.text(1999.6,3.3,'2.6',fontdict=dict(fontsize=12,color='#FF8360',family='Arial Narrow'))
ax.plot(2000,14.2,marker='o',color='#AAADC4',markerfacecolor='w',ms=12)
ax.text(1999.8,14.9,'14.2',fontdict=dict(fontsize=12,color='#AAADC4',family='Arial Narrow'))
ax.plot(2000,6.9,marker='o',color='#5C946E',markerfacecolor='w',ms=12)
ax.text(1999.8,7.6,'6.9',fontdict=dict(fontsize=12,color='#5C946E',family='Arial Narrow'))

# Draw the end points
ax.plot(2016,6.2,marker='o',color='#595758',markerfacecolor='w',ms=12)
ax.text(2015.8,6.9,'6.2',fontdict=dict(fontsize=12,color='#595758',family='Arial Narrow'))
ax.plot(2016,19,marker='o',color='#FF8360',markerfacecolor='w',ms=12)
ax.text(2015.8,19.7,'19.0',fontdict=dict(fontsize=12,color='#FF8360',family='Arial Narrow'))
ax.plot(2016,18,marker='o',color='#AAADC4',markerfacecolor='w',ms=12)
ax.text(2015.8,16.7,'18.0',fontdict=dict(fontsize=12,color='#AAADC4',family='Arial Narrow'))
ax.plot(2016,12.7,marker='o',color='#5C946E',markerfacecolor='w',ms=12)
ax.text(2015.8,13.4,'12.7',fontdict=dict(fontsize=12,color='#5C946E',family='Arial Narrow'))

#draw the ledgends at the tail of each line
ax.text(2014,22,"Self-financial sub-degree",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,16.1,"Publicly-funded undergraduate",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,10,"Publicly-funded sub-degree",fontdict=dict(fontsize=12,family='Arial Narrow'))
ax.text(2014,5,"Self-financial undergraduate",fontdict=dict(fontsize=12,family='Arial Narrow'))
plt.title("HongKongers' participation in four education programs",fontsize=24)

#draw the turning point
ax.plot(2003,9.1,marker="o",color='#FF8360',markerfacecolor='w',ms=10)
ax.annotate("turning point",xy=(2003,9.0),xytext=(2003.5, 7),# xycoords="figure points",
            arrowprops=dict(arrowstyle="->", color="black"))

#draw the highest point
ax.plot(2012,33.4,c='#FF8360',marker="o",markerfacecolor='w',ms=10)
ax.text(2011.8,34,"33.4",fontdict=dict(fontsize=12,family='Arial Narrow',color='#FF8360'))

# Set ticks and show the diagram
my_x_ticks = np.arange(2000,2017, 4)
plt.xticks(my_x_ticks)
ax.set_xticklabels(('2000-01','2004-05','2008-09', '2012-13', '2016-17'))
plt.xlim((1999.5,2018))
xminorLocator = MultipleLocator(1) 
ax.xaxis.set_minor_locator(xminorLocator)
plt.yticks([])
plt.show()
# Out:
# C:\Users\Public\anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['Arial Narrow'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
